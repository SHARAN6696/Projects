# %% [markdown]
# # MiTH (BATCH 75)

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Importing the data sets

# %%
#Get current working directory
import os
os.getcwd()
# Out:
# 'C:\\Users\\SHARAN SURESH\\Desktop\\Git'

# %%
#Import training set
train = pd.read_excel("train_data-1578037482430.xlsx",na_values='unknown')
#Import test set
test =  pd.read_excel("test_data-1578037501169.xlsx",na_values='unknown')

# %%
train
# Out:
#      CustomerID  CustomerName  yearofBirth  monthofBirth  dayofBirth  \
# 0      C5814651  Name_5814651         1980             5          12
# 1      C6465787  Name_6465787         1986            12          28
# 2      C3824349  Name_3824349         1999            11          23
# 3      C8431888  Name_8431888         1969             4           6
# 4      C2944860  Name_2944860         1993             6          15
# ...         ...           ...          ...           ...         ...
# 7355   C5312907  Name_5312907         1980            12          12
# 7356   C5373454  Name_5373454         1951             9          27
# 7357   C6167603  Name_6167603         1958            12          21
# 7358   C3300290  Name_3300290         1985             4          28
# 7359   C6659081  Name_6659081         1976             2          25
#
#       yearofEntry  monthofEntry  dayofEntry  Gender    Location  ...  \
# ...

# %%
test
# Out:
#      CustomerID  CustomerName  yearofBirth  monthofBirth  dayofBirth  \
# 0      C5993228  Name_5993228         1972             5           5
# 1      C6546925  Name_6546925         1990            12          27
# 2      C7491750  Name_7491750         1966             7          25
# 3      C8462011  Name_8462011         1983             7           7
# 4      C3187447  Name_3187447         1983             8           9
# ...         ...           ...          ...           ...         ...
# 1835   C5458876  Name_5458876         1980             3          11
# 1836   C4306823  Name_4306823         1982             5          19
# 1837   C2409933  Name_2409933         1983            10           7
# 1838   C5212350  Name_5212350         1995             2          13
# 1839   C4383485  Name_4383485         1969             6          28
#
#       yearofEntry  monthofEntry  dayofEntry  Gender    Location  Education  \
# ...

# %%
print(train.shape)
print(test.shape)
# Out:
# (7360, 21)
# (1840, 20)

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %%
#Training data
train
# Out:
#      CustomerID  CustomerName  yearofBirth  monthofBirth  dayofBirth  \
# 0      C5814651  Name_5814651         1980             5          12
# 1      C6465787  Name_6465787         1986            12          28
# 2      C3824349  Name_3824349         1999            11          23
# 3      C8431888  Name_8431888         1969             4           6
# 4      C2944860  Name_2944860         1993             6          15
# ...         ...           ...          ...           ...         ...
# 7355   C5312907  Name_5312907         1980            12          12
# 7356   C5373454  Name_5373454         1951             9          27
# 7357   C6167603  Name_6167603         1958            12          21
# 7358   C3300290  Name_3300290         1985             4          28
# 7359   C6659081  Name_6659081         1976             2          25
#
#       yearofEntry  monthofEntry  dayofEntry  Gender    Location  ...  \
# ...

# %%
train.head()
# Out:
#   CustomerID  CustomerName  yearofBirth  monthofBirth  dayofBirth  \
# 0   C5814651  Name_5814651         1980             5          12
# 1   C6465787  Name_6465787         1986            12          28
# 2   C3824349  Name_3824349         1999            11          23
# 3   C8431888  Name_8431888         1969             4           6
# 4   C2944860  Name_2944860         1993             6          15
#
#    yearofEntry  monthofEntry  dayofEntry  Gender    Location  ...  \
# 0         2014            11          28    Male  Location11  ...
# 1         2011             8          17  Female  Location13  ...
# 2         2013            12           9    Male  Location13  ...
# 3         2015            12          12  Female  Location11  ...
# 4         2012            10          10    Male  Location13  ...
#
#   MaritalStatus  Occupation Ownhouse CreditScore  AccountBalance  \
# 0      divorced  management       no         716            0.00
# ...

# %%
train.tail()
# Out:
#      CustomerID  CustomerName  yearofBirth  monthofBirth  dayofBirth  \
# 7355   C5312907  Name_5312907         1980            12          12
# 7356   C5373454  Name_5373454         1951             9          27
# 7357   C6167603  Name_6167603         1958            12          21
# 7358   C3300290  Name_3300290         1985             4          28
# 7359   C6659081  Name_6659081         1976             2          25
#
#       yearofEntry  monthofEntry  dayofEntry  Gender    Location  ...  \
# 7355         2014            12          14  Female  Location12  ...
# 7356         2013             2           7    Male  Location13  ...
# 7357         2011             2          28    Male  Location11  ...
# 7358         2012            12          18  Female  Location11  ...
# 7359         2018             2           8  Female  Location12  ...
#
#      MaritalStatus  Occupation Ownhouse CreditScore  AccountBalance  \
# ...

# %%
train.shape
# Out:
# (7360, 21)

# %%
train.describe()
# Out:
#        yearofBirth  monthofBirth   dayofBirth  yearofEntry  monthofEntry  \
# count  7360.000000   7360.000000  7360.000000  7360.000000   7360.000000
# mean   1979.058832      6.540897    14.607201  2012.984783      6.477174
# std      10.464673      3.432135     8.068158     2.898385      3.433252
# min    1926.000000      1.000000     1.000000  2008.000000      1.000000
# 25%    1974.000000      4.000000     8.000000  2010.000000      4.000000
# 50%    1981.000000      7.000000    15.000000  2013.000000      6.000000
# 75%    1986.000000     10.000000    22.000000  2015.250000      9.000000
# max    2000.000000     12.000000    28.000000  2018.000000     12.000000
#
#         dayofEntry  CreditScore  AccountBalance  NumberOfProducts  \
# count  7360.000000  7360.000000     7360.000000       7360.000000
# mean     14.505571   650.648777    76601.068011          1.524592
# std       8.020220    96.769231    62442.214871          0.577415
# ...

# %%
train.describe(include="all")
# Out:
#        CustomerID  CustomerName  yearofBirth  monthofBirth   dayofBirth  \
# count        7360          7360  7360.000000   7360.000000  7360.000000
# unique       7360          7360          NaN           NaN          NaN
# top      C4208031  Name_6659839          NaN           NaN          NaN
# freq            1             1          NaN           NaN          NaN
# mean          NaN           NaN  1979.058832      6.540897    14.607201
# std           NaN           NaN    10.464673      3.432135     8.068158
# min           NaN           NaN  1926.000000      1.000000     1.000000
# 25%           NaN           NaN  1974.000000      4.000000     8.000000
# 50%           NaN           NaN  1981.000000      7.000000    15.000000
# 75%           NaN           NaN  1986.000000     10.000000    22.000000
# max           NaN           NaN  2000.000000     12.000000    28.000000
#
#         yearofEntry  monthofEntry   dayofEntry Gender    Location  ...  \
# ...

# %%
train.describe(include="object")
# Out:
#        CustomerID  CustomerName Gender    Location Education MaritalStatus  \
# count        7360          7360   7360        7360      5500          7360
# unique       7360          7360      2           3         3             3
# top      C4208031  Name_6659839   Male  Location11   primary        single
# freq            1             1   3994        3693      1864          2559
#
#        Occupation Ownhouse
# count        6579     7169
# unique          6        2
# top        admin.       no
# freq         3207     3684

# %%
train.describe(include="int64")
# Out:
#        yearofBirth  monthofBirth   dayofBirth  yearofEntry  monthofEntry  \
# count  7360.000000   7360.000000  7360.000000  7360.000000   7360.000000
# mean   1979.058832      6.540897    14.607201  2012.984783      6.477174
# std      10.464673      3.432135     8.068158     2.898385      3.433252
# min    1926.000000      1.000000     1.000000  2008.000000      1.000000
# 25%    1974.000000      4.000000     8.000000  2010.000000      4.000000
# 50%    1981.000000      7.000000    15.000000  2013.000000      6.000000
# 75%    1986.000000     10.000000    22.000000  2015.250000      9.000000
# max    2000.000000     12.000000    28.000000  2018.000000     12.000000
#
#         dayofEntry  CreditScore  NumberOfProducts  IsCreditCardCustomer  \
# count  7360.000000  7360.000000       7360.000000           7360.000000
# mean     14.505571   650.648777          1.524592              0.704212
# std       8.020220    96.769231          0.577415              0.456427
# ...

# %%
train.describe(include="float64")
# Out:
#        AccountBalance         Salary
# count     7360.000000    7360.000000
# mean     76601.068011   99967.894062
# std      62442.214871   57342.390262
# min          0.000000      11.580000
# 25%          0.000000   51361.780000
# 50%      96913.725000   99446.940000
# 75%     127660.767500  149068.075000
# max     250898.090000  199992.480000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7360 entries, 0 to 7359
# Data columns (total 21 columns):
# CustomerID              7360 non-null object
# CustomerName            7360 non-null object
# yearofBirth             7360 non-null int64
# monthofBirth            7360 non-null int64
# dayofBirth              7360 non-null int64
# yearofEntry             7360 non-null int64
# monthofEntry            7360 non-null int64
# dayofEntry              7360 non-null int64
# Gender                  7360 non-null object
# Location                7360 non-null object
# Education               5500 non-null object
# MaritalStatus           7360 non-null object
# Occupation              6579 non-null object
# Ownhouse                7169 non-null object
# CreditScore             7360 non-null int64
# AccountBalance          7360 non-null float64
# NumberOfProducts        7360 non-null int64
# IsCreditCardCustomer    7360 non-null int64
# ActiveMember            7360 non-null int64
# ...

# %%
train.dtypes
# Out:
# CustomerID               object
# CustomerName             object
# yearofBirth               int64
# monthofBirth              int64
# dayofBirth                int64
# yearofEntry               int64
# monthofEntry              int64
# dayofEntry                int64
# Gender                   object
# Location                 object
# Education                object
# MaritalStatus            object
# Occupation               object
# Ownhouse                 object
# CreditScore               int64
# AccountBalance          float64
# NumberOfProducts          int64
# IsCreditCardCustomer      int64
# ActiveMember              int64
# Salary                  float64
# Churn                     int64
# dtype: object

# %%
train.index.values
# Out:
# array([   0,    1,    2, ..., 7357, 7358, 7359], dtype=int64)

# %%
train.columns.values
# Out:
# array(['CustomerID', 'CustomerName', 'yearofBirth', 'monthofBirth',
#        'dayofBirth', 'yearofEntry', 'monthofEntry', 'dayofEntry',
#        'Gender', 'Location', 'Education', 'MaritalStatus', 'Occupation',
#        'Ownhouse', 'CreditScore', 'AccountBalance', 'NumberOfProducts',
#        'IsCreditCardCustomer', 'ActiveMember', 'Salary', 'Churn'],
#       dtype=object)

# %%
train.index.values.size
# Out:
# 7360

# %%
train.columns.values.size
# Out:
# 21

# %% [markdown]
# ### Subsetting training data

# %%
train.iloc[241,7]
# Out:
# 9

# %%
train.iloc[7000:,:10]
# Out:
#      CustomerID  CustomerName  yearofBirth  monthofBirth  dayofBirth  \
# 7000   C5227911  Name_5227911         1993             4          11
# 7001   C6357597  Name_6357597         1977            12          26
# 7002   C7154500  Name_7154500         1977             1          11
# 7003   C4681881  Name_4681881         1992             7          13
# 7004   C6067399  Name_6067399         1986             8          25
# ...         ...           ...          ...           ...         ...
# 7355   C5312907  Name_5312907         1980            12          12
# 7356   C5373454  Name_5373454         1951             9          27
# 7357   C6167603  Name_6167603         1958            12          21
# 7358   C3300290  Name_3300290         1985             4          28
# 7359   C6659081  Name_6659081         1976             2          25
#
#       yearofEntry  monthofEntry  dayofEntry  Gender    Location
# 7000         2010            11           7    Male  Location12
# ...

# %%
train.iloc[[100,200,1000],[0,7,9,18]]
# Out:
#      CustomerID  dayofEntry    Location  ActiveMember
# 100    C6980423           8  Location12             1
# 200    C5546100          25  Location12             0
# 1000   C8838156          20  Location12             1

# %%
train.loc[:25,"Salary"]
# Out:
# 0     189678.70
# 1      61936.22
# 2     193008.52
# 3        738.88
# 4      78358.94
# 5      48682.10
# 6     131834.75
# 7     188974.81
# 8     172668.39
# 9      99298.80
# 10     79146.36
# 11     29483.87
# 12    178747.43
# 13    185366.56
# 14    148238.16
# 15     71638.00
# 16    101433.76
# 17     73470.98
# 18     22527.27
# 19    125518.32
# 20    147913.56
# 21     33099.41
# 22     92888.52
# 23    161971.42
# 24     16717.11
# 25    161574.19
# Name: Salary, dtype: float64

# %%
train.loc[7300:,["Gender","Location","Education"]]
# Out:
#       Gender    Location  Education
# 7300    Male  Location13   tertiary
# 7301  Female  Location12    primary
# 7302  Female  Location12   tertiary
# 7303    Male  Location11        NaN
# 7304  Female  Location12   tertiary
# 7305    Male  Location11    primary
# 7306    Male  Location12        NaN
# 7307    Male  Location11   tertiary
# 7308    Male  Location13        NaN
# 7309    Male  Location13        NaN
# 7310  Female  Location11        NaN
# 7311  Female  Location11    primary
# 7312    Male  Location12        NaN
# 7313    Male  Location12        NaN
# 7314    Male  Location13        NaN
# 7315    Male  Location11    primary
# 7316  Female  Location11        NaN
# 7317    Male  Location11    primary
# 7318  Female  Location12   tertiary
# 7319    Male  Location11        NaN
# 7320    Male  Location13   tertiary
# 7321  Female  Location11    primary
# 7322  Female  Location11    primary
# 7323  Female  Location11    primary
# 7324  Female  Location11        NaN
# ...

# %%
train.loc[:,:]
# Out:
#      CustomerID  CustomerName  yearofBirth  monthofBirth  dayofBirth  \
# 0      C5814651  Name_5814651         1980             5          12
# 1      C6465787  Name_6465787         1986            12          28
# 2      C3824349  Name_3824349         1999            11          23
# 3      C8431888  Name_8431888         1969             4           6
# 4      C2944860  Name_2944860         1993             6          15
# ...         ...           ...          ...           ...         ...
# 7355   C5312907  Name_5312907         1980            12          12
# 7356   C5373454  Name_5373454         1951             9          27
# 7357   C6167603  Name_6167603         1958            12          21
# 7358   C3300290  Name_3300290         1985             4          28
# 7359   C6659081  Name_6659081         1976             2          25
#
#       yearofEntry  monthofEntry  dayofEntry  Gender    Location  ...  \
# ...

# %%
train.loc[:,"monthofEntry"]
# Out:
# 0       11
# 1        8
# 2       12
# 3       12
# 4       10
#         ..
# 7355    12
# 7356     2
# 7357     2
# 7358    12
# 7359     2
# Name: monthofEntry, Length: 7360, dtype: int64

# %%
train.loc[764,"Occupation"]
# Out:
# 'admin.'

# %%
train.loc[[7,19,639,2567],"MaritalStatus":"Churn"]
# Out:
#      MaritalStatus     Occupation Ownhouse  CreditScore  AccountBalance  \
# 7         divorced         admin.       no          492        57068.43
# 19        divorced         admin.       no          678            0.00
# 639         single     technician      yes          644            0.00
# 2567      divorced  self-employed       no          661       141136.62
#
#       NumberOfProducts  IsCreditCardCustomer  ActiveMember     Salary  Churn
# 7                    2                     1             0  188974.81      0
# 19                   1                     1             0  125518.32      0
# 639                  2                     1             0  119419.37      0
# 2567                 1                     1             0  189742.78      1

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Data Visualizations

# %%
train.head()
# Out:
#   CustomerID  CustomerName  yearofBirth  monthofBirth  dayofBirth  \
# 0   C5814651  Name_5814651         1980             5          12
# 1   C6465787  Name_6465787         1986            12          28
# 2   C3824349  Name_3824349         1999            11          23
# 3   C8431888  Name_8431888         1969             4           6
# 4   C2944860  Name_2944860         1993             6          15
#
#    yearofEntry  monthofEntry  dayofEntry  Gender    Location  ...  \
# 0         2014            11          28    Male  Location11  ...
# 1         2011             8          17  Female  Location13  ...
# 2         2013            12           9    Male  Location13  ...
# 3         2015            12          12  Female  Location11  ...
# 4         2012            10          10    Male  Location13  ...
#
#   MaritalStatus  Occupation Ownhouse CreditScore  AccountBalance  \
# 0      divorced  management       no         716            0.00
# ...

# %%
train.dtypes
# Out:
# CustomerID               object
# CustomerName             object
# yearofBirth               int64
# monthofBirth              int64
# dayofBirth                int64
# yearofEntry               int64
# monthofEntry              int64
# dayofEntry                int64
# Gender                   object
# Location                 object
# Education                object
# MaritalStatus            object
# Occupation               object
# Ownhouse                 object
# CreditScore               int64
# AccountBalance          float64
# NumberOfProducts          int64
# IsCreditCardCustomer      int64
# ActiveMember              int64
# Salary                  float64
# Churn                     int64
# dtype: object

# %% [markdown]
# ### Count Plots

# %%
sns.countplot(x="Churn",data=train)
plt.show()

# %%
sns.countplot(x="Gender",data=train)
plt.show()

# %%
sns.countplot(x="Location",data=train)
plt.show()

# %%
sns.countplot(x="Education",data=train)
plt.show()

# %%
sns.countplot(x="MaritalStatus",data=train)
plt.show()

# %%
sns.countplot(x="Occupation",data=train)
plt.show()

# %%
sns.countplot(x="Ownhouse",data=train)
plt.show()

# %%
sns.countplot(x="NumberOfProducts",data=train)
plt.show()

# %%
sns.countplot(x="IsCreditCardCustomer",data=train)
plt.show()

# %%
sns.countplot(x="ActiveMember",data=train)
plt.show()

# %%
sns.countplot(x="Churn",hue="Gender",data=train)
plt.show()

# %%
sns.countplot(x="Churn",hue="Location",data=train)
plt.show()

# %%
sns.countplot(x="Churn",hue="Education",data=train)
plt.show()

# %%
sns.countplot(x="Churn",hue="MaritalStatus",data=train)
plt.show()

# %%
sns.countplot(x="Churn",hue="Occupation",data=train)
plt.show()

# %%
sns.countplot(x="Churn",hue="Ownhouse",data=train)
plt.show()

# %%
sns.countplot(x="Churn",hue="NumberOfProducts",data=train)
plt.show()

# %%
sns.countplot(x="Churn",hue="IsCreditCardCustomer",data=train)
plt.show()

# %%
sns.countplot(x="Churn",hue="ActiveMember",data=train)
plt.show()

# %%
train["AccountBalance"].plot.hist(bins=15,figsize=(10,5),color="red")
plt.show()

# %% [markdown]
# ### Relationship Plots

# %%
sns.relplot(x="AccountBalance",y="CreditScore",hue=None,kind="scatter",data=train)
plt.title("Credit Score vs Account Balance")
plt.show()

# %%
sns.relplot(x="AccountBalance",y="CreditScore",hue="MaritalStatus",kind="scatter",data=train)
plt.title("Credit Score vs Account Balance")
plt.show()

# %%
sns.relplot(x="AccountBalance",y="CreditScore",hue="Education",kind="scatter",data=train)
plt.title("Credit Score vs Account Balance")
plt.show()

# %%
sns.relplot(x="AccountBalance",y="CreditScore",hue="Occupation",kind="scatter",data=train)
plt.title("Credit Score vs Account Balance")
plt.show()

# %%
sns.relplot(x="AccountBalance",y="CreditScore",hue="Location",kind="scatter",data=train)
plt.title("Credit Score vs Account Balance")
plt.show()

# %%
sns.relplot(x="AccountBalance",y="CreditScore",hue="Gender",kind="scatter",data=train)
plt.title("Credit Score vs Account Balance")
plt.show()

# %%
sns.relplot(x="AccountBalance",y="CreditScore",hue="Ownhouse",kind="scatter",data=train)
plt.title("Credit Score vs Account Balance")
plt.show()

# %%
sns.relplot(x="AccountBalance",y="CreditScore",hue="NumberOfProducts",kind="scatter",data=train)
plt.title("Credit Score vs Account Balance")
plt.show()

# %%
sns.relplot(x="AccountBalance",y="CreditScore",hue="ActiveMember",kind="scatter",data=train)
plt.title("Credit Score vs Account Balance")
plt.show()

# %%
sns.relplot(x=np.array(train["Salary"])/1000,y="CreditScore",hue=None,kind="scatter",data=train)
plt.title("Credit Score vs Salary (in '000s)")
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\matplotlib\text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
sns.relplot(x=np.array(train["Salary"])/1000,y="CreditScore",hue="MaritalStatus",kind="scatter",data=train)
plt.title("Credit Score vs Salary (in '000s)")
plt.show()

# %%
sns.relplot(x=np.array(train["Salary"])/1000,y="CreditScore",hue="Occupation",kind="scatter",data=train)
plt.title("Credit Score vs Salary (in '000s)")
plt.show()

# %%
sns.relplot(x=np.array(train["Salary"])/1000,y="CreditScore",hue="Gender",kind="scatter",data=train)
plt.title("Credit Score vs Salary (in '000s)")
plt.show()

# %%
sns.relplot(x=np.array(train["Salary"])/1000,y="CreditScore",hue="Ownhouse",kind="scatter",data=train)
plt.title("Credit Score vs Salary (in '000s)")
plt.show()

# %%
sns.relplot(x=np.array(train["Salary"])/1000,y="CreditScore",hue="NumberOfProducts",kind="scatter",data=train)
plt.title("Credit Score vs Salary (in '000s)")
plt.show()

# %%
sns.relplot(x=np.array(train["Salary"])/1000,y="CreditScore",hue="ActiveMember",kind="scatter",data=train)
plt.title("Credit Score vs Salary (in '000s)")
plt.show()

# %% [markdown]
# ### Categorical Plots

# %%
train.dtypes
# Out:
# CustomerID               object
# CustomerName             object
# yearofBirth               int64
# monthofBirth              int64
# dayofBirth                int64
# yearofEntry               int64
# monthofEntry              int64
# dayofEntry                int64
# Gender                   object
# Location                 object
# Education                object
# MaritalStatus            object
# Occupation               object
# Ownhouse                 object
# CreditScore               int64
# AccountBalance          float64
# NumberOfProducts          int64
# IsCreditCardCustomer      int64
# ActiveMember              int64
# Salary                  float64
# Churn                     int64
# dtype: object

# %%
sns.catplot(x="Churn",y="CreditScore",kind="violin",data=train)
plt.show()

# %%
sns.catplot(x="Gender",y="CreditScore",kind="box",data=train)
plt.show()

# %%
sns.catplot(x="Occupation",y="CreditScore",kind="box",data=train)
plt.show()

# %%
sns.catplot(x="Education",y="CreditScore",kind="box",data=train)
plt.show()

# %%
sns.catplot(x="Location",y="CreditScore",kind="box",data=train)
plt.show()

# %%
sns.catplot(x="MaritalStatus",y="CreditScore",kind="box",data=train)
plt.show()

# %%
sns.catplot(x="ActiveMember",y="CreditScore",kind="box",data=train)
plt.show()

# %%
sns.catplot(x="NumberOfProducts",y="CreditScore",kind="box",data=train)
plt.show()

# %%
sns.catplot(x="Ownhouse",y="CreditScore",kind="box",data=train)
plt.show()

# %%
sns.catplot(x="IsCreditCardCustomer",y="CreditScore",kind="box",data=train)
plt.show()

# %%
sns.catplot(x="Churn",y="CreditScore",kind="box",data=train)
plt.show()

# %% [markdown]
# ### Pair Plots

# %%
sns.set(style="whitegrid")
b=sns.PairGrid(train.drop(['CustomerID', 'CustomerName', 'yearofBirth', 'monthofBirth',
       'dayofBirth', 'yearofEntry', 'monthofEntry', 'dayofEntry'],axis=1),hue='Churn')
b.map(plt.scatter)
plt.show()

# %% [markdown]
# ###  Histograms

# %%
g=sns.FacetGrid(train,col="Churn",row="Gender")
g=g.map(plt.hist,"CreditScore")

# %%
g=sns.FacetGrid(train,col="Churn",row="Education")
g=g.map(plt.hist,"CreditScore",color="green")

# %%
g=sns.FacetGrid(train,col="Churn",row="ActiveMember")
g=g.map(plt.hist,"CreditScore",color="orange")

# %%
g=sns.FacetGrid(train,col="Churn",row="MaritalStatus")
g=g.map(plt.hist,"CreditScore",color="yellow")

# %%
g=sns.FacetGrid(train,col="Churn",row="IsCreditCardCustomer")
g=g.map(plt.hist,"CreditScore",color="purple")

# %%
g=sns.FacetGrid(train,col="Churn",row="Location")
g=g.map(plt.hist,"CreditScore",color="indigo")

# %%
g=sns.FacetGrid(train,col="Churn",row="Ownhouse")
g=g.map(plt.hist,"CreditScore",color="violet")

# %%
g=sns.FacetGrid(train,col="Churn",row="NumberOfProducts")
g=g.map(plt.hist,"CreditScore",color="pink")

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Feature engineering

# %%
train.head()

# %% [markdown]
# ### Dropping irrelevant columns

# %%
train=train.drop(['CustomerID','CustomerName'],axis=1)

# %%
#Age in years
train["Age"]=((2020-train["yearofBirth"])*365+(train["monthofBirth"]-1)*30+train["dayofBirth"])/365
train["Age"].head()

# %%
#tenure
train["tenure"]=((2020-train["yearofEntry"])*365+(train["monthofEntry"]-1)*30+train["dayofEntry"])/365
train["tenure"].head()

# %%
train.head()

# %%
train=train.drop(['yearofBirth','monthofBirth','dayofBirth','yearofEntry','monthofEntry','dayofEntry'],axis=1)

# %%
train.head()

# %%
train.dtypes

# %%
train.shape

# %% [markdown]
# ### Converting to categorical type

# %%
train[['Gender', 'Location', 'Education', 'MaritalStatus', 'Occupation','Ownhouse',
       ]]=train[['Gender', 'Location', 'Education', 'MaritalStatus', 'Occupation','Ownhouse',
      ]].astype("category")

# %%
train.head()

# %%
train.dtypes

# %%
train.isnull().sum()

# %% [markdown]
# ### Imputation of null values

# %%
train.Education.mode()[0]

# %%
train.Education.fillna(train.Education.mode()[0],inplace=True)

# %%
train.Occupation.mode()[0]

# %%
train.Occupation.fillna(train.Occupation.mode()[0],inplace=True)

# %%
train.Ownhouse.mode()[0]

# %%
train.Ownhouse.fillna(train.Ownhouse.mode()[0],inplace=True)

# %%
train.isnull().sum()

# %%
train.dtypes

# %%
train.nunique()

# %%
categorical_Attributes = train.select_dtypes(include=['category']).columns

# %%
categorical_Attributes

# %%
dummy=['Education','Location','Gender','MaritalStatus','Occupation','Ownhouse']

# %% [markdown]
# ### Dummification of categorical attributes

# %%
train = pd.get_dummies(columns=dummy, data=train, 
                      prefix=dummy, prefix_sep="_", drop_first=True)

# %%
train

# %%
train['IsCreditCardCustomer'].value_counts()

# %%
train['ActiveMember'].value_counts()

# %%
train['NumberOfProducts'].value_counts()

# %%
# train['tenure']

# %%
train.shape

# %%
train.dtypes

# %% [markdown]
# ## Test data pre-processing

# %%
test.head()

# %%
test=test.drop(['CustomerID','CustomerName'],axis=1)

# %%
#Age in years
test["Age"]=((2020-test["yearofBirth"])*365+(test["monthofBirth"]-1)*30+test["dayofBirth"])/365
test["Age"].head()

# %%
#tenure
test["tenure"]=((2020-test["yearofEntry"])*365+(test["monthofEntry"]-1)*30+test["dayofEntry"])/365
test["tenure"].head()

# %%
test.head()

# %%
test=test.drop(['yearofBirth','monthofBirth','dayofBirth','yearofEntry','monthofEntry','dayofEntry'],axis=1)

# %%
test.head(5)

# %%
test.isnull().sum()

# %% [markdown]
# ### Imputation of null values

# %%
test[['Gender', 'Location', 'Education', 'MaritalStatus', 'Occupation','Ownhouse',
       ]]=test[['Gender', 'Location', 'Education', 'MaritalStatus', 'Occupation','Ownhouse',
      ]].astype("category")

# %%
test.Education.mode()[0]

# %%
test.Education.fillna(test.Education.mode()[0],inplace=True)

# %%
test.Occupation.mode()[0]

# %%
test.Occupation.fillna(test.Occupation.mode()[0],inplace=True)

# %%
test.Ownhouse.mode()[0]

# %%
test.Ownhouse.fillna(test.Ownhouse.mode()[0],inplace=True)

# %%
test.isnull().sum()

# %%
test.dtypes

# %%
categorical_Attributes = test.select_dtypes(include=['category']).columns

# %%
categorical_Attributes

# %%
dummy=['Education','Location','Gender','MaritalStatus','Occupation','Ownhouse']

# %% [markdown]
# ### Dummification of categorical variables

# %%
test = pd.get_dummies(columns=dummy, data=test, 
                      prefix=dummy, prefix_sep="_", drop_first=True)

# %%
test.head()

# %%
test.dtypes

# %% [markdown]
# ## Model Building

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from sklearn import tree
from sklearn.model_selection import GridSearchCV

# %%
X=train.drop("Churn",axis=1)
y=train["Churn"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=123)

# %%
# num_attr=X_train.select_dtypes(['int64','float64']).columns

# %%
num_att=['CreditScore','AccountBalance','NumberOfProducts','tenure','Salary','Age']

# %% [markdown]
# ### Scaling the numerical attributes

# %%
scaler = StandardScaler()
scaler.fit(X_train[num_att])
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
## Standardize the train data
X_train[num_att]=scaler.transform(X_train[num_att])
## Standardize the test data
X_test[num_att]=scaler.transform(X_test[num_att])
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
X_test_final=test

# %%
X_test_final
# Out:
#       CreditScore  AccountBalance  NumberOfProducts  IsCreditCardCustomer  \
# 0             624            0.00                 2                     1
# 1             777       134571.50                 1                     0
# 2             707            0.00                 1                     1
# 3             746       172274.01                 1                     1
# 4             762            0.00                 2                     1
# ...           ...             ...               ...                   ...
# 1835          535       119272.29                 1                     0
# 1836          711       137688.71                 1                     1
# 1837          603       145623.36                 1                     1
# 1838          536        92366.72                 2                     1
# 1839          699            0.00                 1                     0
#
#       ActiveMember     Salary        Age     tenure  Education_secondary  \
# ...

# %%
X_test_final[num_att]=scaler.transform(X_test_final[num_att])

# %%
# X_test_final

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (6256, 21)
# (1104, 21)

# %%
X_test.head(4)
# Out:
#       CreditScore  AccountBalance  NumberOfProducts  IsCreditCardCustomer  \
# 3993     1.122819        0.238448         -0.915096                     1
# 6649    -1.395263        0.453570         -0.915096                     1
# 6188    -1.673903       -1.225643          0.815509                     0
# 6696     0.317858        0.618929         -0.915096                     0
#
#       ActiveMember    Salary       Age    tenure  Education_secondary  \
# 3993             0  0.295872  0.974477  1.269861                    0
# 6649             0  0.270729  0.659860 -1.381631                    0
# 6188             1  1.286239  1.110435 -0.549164                    0
# 6696             0 -1.331940  0.459458 -0.595203                    0
#
#       Education_tertiary  ...  Location_Location13  Gender_Male  \
# 3993                   0  ...                    0            0
# 6649                   0  ...                    0            0
# ...

# %%
train.dtypes
# Out:
# CreditScore                   int64
# AccountBalance              float64
# NumberOfProducts              int64
# IsCreditCardCustomer          int64
# ActiveMember                  int64
# Salary                      float64
# Churn                         int64
# Age                         float64
# tenure                      float64
# Education_secondary           uint8
# Education_tertiary            uint8
# Location_Location12           uint8
# Location_Location13           uint8
# Gender_Male                   uint8
# MaritalStatus_married         uint8
# MaritalStatus_single          uint8
# Occupation_management         uint8
# Occupation_retired            uint8
# Occupation_self-employed      uint8
# Occupation_services           uint8
# Occupation_technician         uint8
# Ownhouse_yes                  uint8
# dtype: object

# %%
print(pd.value_counts(y_train))
print(pd.value_counts(y_test))
# Out:
# 0    4982
# 1    1274
# Name: Churn, dtype: int64
# 0    886
# 1    218
# Name: Churn, dtype: int64

# %% [markdown]
# ## Decision Tree

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %%
clf.feature_importances_
# Out:
# array([0.10002774, 0.1185689 , 0.11016566, 0.01486798, 0.05985382,
#        0.09317494, 0.27211581, 0.10268557, 0.01200335, 0.00878036,
#        0.02089282, 0.00980412, 0.01661234, 0.01188481, 0.01179427,
#        0.00608294, 0.00039426, 0.00552724, 0.00351081, 0.00916809,
#        0.01208418])

# %%
features = X.columns
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
pd.DataFrame([X.columns[indices],np.sort(importances)[::-1]])
# Out:
#          0               1                 2         3            4   \
# 0       Age  AccountBalance  NumberOfProducts    tenure  CreditScore
# 1  0.272116        0.118569          0.110166  0.102686     0.100028
#
#           5             6                    7            8   \
# 0     Salary  ActiveMember  Location_Location12  Gender_Male
# 1  0.0931749     0.0598538            0.0208928    0.0166123
#
#                      9   ...                   11                     12  \
# 0  IsCreditCardCustomer  ...  Education_secondary  MaritalStatus_married
# 1              0.014868  ...            0.0120033              0.0118848
#
#                      13                   14                     15  \
# 0  MaritalStatus_single  Location_Location13  Occupation_technician
# 1             0.0117943           0.00980412             0.00916809
#
#                    16                     17                        18  \
# ...

# %%
importances
# Out:
# array([0.10002774, 0.1185689 , 0.11016566, 0.01486798, 0.05985382,
#        0.09317494, 0.27211581, 0.10268557, 0.01200335, 0.00878036,
#        0.02089282, 0.00980412, 0.01661234, 0.01188481, 0.01179427,
#        0.00608294, 0.00039426, 0.00552724, 0.00351081, 0.00916809,
#        0.01208418])

# %%
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='black')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
train_pred = clf.predict(X_train)
test_pred = clf.predict(X_test)

# %%
confusion_matrix_test = confusion_matrix(y_test, test_pred)
confusion_matrix_train = confusion_matrix(y_train, train_pred)

print(confusion_matrix_train)
print(confusion_matrix_test)
# Out:
# [[4982    0]
#  [   0 1274]]
# [[746 140]
#  [103 115]]

# %%
Accuracy_Train=(confusion_matrix_train[0,0]+confusion_matrix_train[1,1])/(confusion_matrix_train[0,0]+confusion_matrix_train[0,1]+confusion_matrix_train[1,0]+confusion_matrix_train[1,1])
TNR_Train= confusion_matrix_train[0,0]/(confusion_matrix_train[0,0]+confusion_matrix_train[0,1])
TPR_Train= confusion_matrix_train[1,1]/(confusion_matrix_train[1,0]+confusion_matrix_train[1,1])

print("Train TNR: ",TNR_Train)
print("Train TPR: ",TPR_Train)
print("Train Accuracy: ",Accuracy_Train)
# Out:
# Train TNR:  1.0
# Train TPR:  1.0
# Train Accuracy:  1.0

# %%
Accuracy_Test=(confusion_matrix_test[0,0]+confusion_matrix_test[1,1])/(confusion_matrix_test[0,0]+confusion_matrix_test[0,1]+confusion_matrix_test[1,0]+confusion_matrix_test[1,1])
TNR_Test= confusion_matrix_test[0,0]/(confusion_matrix_test[0,0] +confusion_matrix_test[0,1])
TPR_Test= confusion_matrix_test[1,1]/(confusion_matrix_test[1,0] +confusion_matrix_test[1,1])

print("Test TNR: ",TNR_Test)
print("Test TPR: ",TPR_Test)
print("Test Accuracy: ",Accuracy_Test)
# Out:
# Test TNR:  0.8419864559819413
# Test TPR:  0.5275229357798165
# Test Accuracy:  0.779891304347826

# %%
from sklearn import metrics

# %%
metrics.f1_score(y_test, test_pred)
# Out:
# 0.4862579281183932

# %%
test_pred_test = clf.predict(X_test_final)

# %%
new_series = pd.Series(test_pred_test)

# %%
final_predictions=new_series.to_frame()

# %%
test2 =  pd.read_excel("test_data-1578037501169.xlsx",na_values='unknown')
cust=test2['CustomerID'].to_frame()

# %%
final=pd.concat([cust,final_predictions ],axis=1)
final.rename(columns={0:'Churn'}, inplace=True)

# %%
final.to_csv(r'C:\Users\SHARAN SURESH\Desktop\MITH2020\Exam\Exampredictions4.csv',index=False)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=1000,max_depth=20)
rf.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=20, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

y_pred = rf.predict(X_train)
print("Accuracy for Train set:")
print(accuracy_score(y_train,y_pred))

y_pred_test = rf.predict(X_test)
print("Accuracy for Test set:")
print(accuracy_score(y_test,y_pred_test))

print("\n")

print("Recall for Train set:")
print(recall_score(y_train,y_pred,pos_label=1))

print("Recall for Test set:")
print(recall_score(y_test,y_pred_test,pos_label=1))

print("\n")

print("Precision for Train set:")
print(precision_score(y_train,y_pred,pos_label=1))

print("Precision for Test set:")
print(precision_score(y_test,y_pred_test,pos_label=1))

print("\n")

print("F1_Score for Test set:")
print(metrics.f1_score(y_test,y_pred_test,pos_label=1))
# Out:
# Accuracy for Train set:
# 1.0
# Accuracy for Test set:
# 0.8614130434782609
#
#
# Recall for Train set:
# 1.0
# Recall for Test set:
# 0.42660550458715596
#
#
# Precision for Train set:
# 1.0
# Precision for Test set:
# 0.768595041322314
#
#
# F1_Score for Test set:
# 0.5486725663716815

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

rfc = RandomForestClassifier(n_jobs=-1, max_features='sqrt') 
 
# Use a grid over parameters of interest
param_grid = { 
           "n_estimators" : [9, 18, 27, 36, 45, 54, 63],
           "max_depth" : [2,3,5,7],
           "min_samples_leaf" : [2, 4]}

scores = ['precision', 'recall']

# %%
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid,cv=5,scoring='f1')
CV_rfc.fit(X=X_train, y=y_train)
# Out:
# E:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
print(CV_rfc.best_score_, CV_rfc.best_params_)
# Out:
# 0.48895094209940737 {'max_depth': 7, 'min_samples_leaf': 2, 'n_estimators': 54}

# %%
y_pred_test=rf.predict(X_test)
print(accuracy_score(y_test,y_pred_test))
# Out:
# 0.8568840579710145

# %% [markdown]
# ## XGBoost

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier

from xgboost import XGBClassifier

# %%
XGB_model = XGBClassifier(n_estimators=1000, gamma=0.5,learning_rate=0.1,max_depth=25)
# %time XGB_model.fit(X_train, y_train)
y_pred = XGB_model.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# Wall time: 47 s
# 0.8596014492753623

# %%
print(metrics.f1_score(y_test,y_pred))
# Out:
# 0.5822102425876011

# %%
XGB = XGBClassifier(n_jobs=-1)
 
# Use a grid over parameters of interest
param_grid = {
     'colsample_bytree': np.linspace(0.5, 0.9, 2),
     'n_estimators':[100,500],
     'max_depth': [10, 15,25]
}

 
CV_XGB = GridSearchCV(estimator=XGB, param_grid=param_grid, cv= 10,scoring='f1')

# %%
# %time CV_XGB.fit(X = X, y=y)
# Out:
# Wall time: 13min 22s
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0,
#                                      learning_rate=0.1, max_delta_step=0,
#                                      max_depth=3, min_child_weight=1,
#                                      missing=None, n_estimators=100, n_jobs=-1,
#                                      nthread=None, objective='binary:logistic',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=None, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='warn', n_jobs=None,
#              param_grid={'colsample_bytree': array([0.5, 0.9]),
# ...

# %%
# Find best model
best_xgb_model = CV_XGB.best_estimator_
print (CV_XGB.best_score_, CV_XGB.best_params_)
# Out:
# 0.5717286963491311 {'colsample_bytree': 0.9, 'max_depth': 10, 'n_estimators': 100}

# %%
y_pred_best=best_xgb_model.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8596014492753623

# %%
print(accuracy_score(y_test,y_pred_best))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-331-33b003bd1f58> in <module>
# ----> 1 print(accuracy_score(y_test,y_pred_best))
#
# NameError: name 'y_pred_best' is not defined

# %%
print(confusion_matrix(y_test, y_pred_best))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-188-7a31809fa705> in <module>
# ----> 1 print(confusion_matrix(y_test, y_pred_best))
#
# NameError: name 'y_pred_best' is not defined

# %%
print("F1_Score for Test set:")
print(metrics.f1_score(y_test,y_pred,pos_label=1))
# Out:
# F1_Score for Test set:
# 0.5822102425876011

# %%
# X_test_final

# %%
y_final = XGB_model.predict(X_test_final)

# %%
# y_final=best_xgb_model.predict(X_test_final)

# %%
final_predictions=new_series.to_frame()

# %%
y_final
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
new_series = pd.Series(y_final)

# %%
# y_pred_test_final=best_xgb_model.predict(X_test_final)

# %%
# y_pred_test_final

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92       886
#            1       0.71      0.50      0.58       218
#
#     accuracy                           0.86      1104
#    macro avg       0.80      0.72      0.75      1104
# weighted avg       0.85      0.86      0.85      1104

# %%
test
# Out:
#       CreditScore  AccountBalance  NumberOfProducts  IsCreditCardCustomer  \
# 0       -6.723291       -1.225663         -1.233127                     1
# 1       -6.707051       -1.225628         -4.219412                     0
# 2       -6.714481       -1.225663         -4.219412                     1
# 3       -6.710342       -1.225619         -4.219412                     1
# 4       -6.708643       -1.225663         -1.233127                     1
# ...           ...             ...               ...                   ...
# 1835    -6.732737       -1.225632         -4.219412                     0
# 1836    -6.714057       -1.225628         -4.219412                     1
# 1837    -6.725520       -1.225626         -4.219412                     1
# 1838    -6.732631       -1.225639         -1.233127                     1
# 1839    -6.715330       -1.225663         -4.219412                     0
#
#       ActiveMember    Salary       Age    tenure  Education_secondary  \
# ...

# %%
#### Exporting a

# %%
# new_series = pd.Series(y_pred_test_final)

# %%
# new_series

# %%
# y_final

# %%
final_predictions=new_series.to_frame()

# %%
test
# Out:
#       CreditScore  AccountBalance  NumberOfProducts  IsCreditCardCustomer  \
# 0       -6.723291       -1.225663         -1.233127                     1
# 1       -6.707051       -1.225628         -4.219412                     0
# 2       -6.714481       -1.225663         -4.219412                     1
# 3       -6.710342       -1.225619         -4.219412                     1
# 4       -6.708643       -1.225663         -1.233127                     1
# ...           ...             ...               ...                   ...
# 1835    -6.732737       -1.225632         -4.219412                     0
# 1836    -6.714057       -1.225628         -4.219412                     1
# 1837    -6.725520       -1.225626         -4.219412                     1
# 1838    -6.732631       -1.225639         -1.233127                     1
# 1839    -6.715330       -1.225663         -4.219412                     0
#
#       ActiveMember    Salary       Age    tenure  Education_secondary  \
# ...

# %%
final_predictions.to_csv(r'C:\Users\SHARAN SURESH\Desktop\MITH2020\Exam\Exampredictions.csv',index=False)

# %%
test2 =  pd.read_excel("test_data-1578037501169.xlsx",na_values='unknown')
cust=test2['CustomerID'].to_frame()

# %%
final_predictions
# Out:
#       0
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# ...  ..
# 1835  1
# 1836  1
# 1837  1
# 1838  1
# 1839  1
#
# [1840 rows x 1 columns]

# %%
final=pd.concat([cust,final_predictions ],axis=1)

# %%
final.to_csv(r'C:\Users\SHARAN SURESH\Desktop\MITH2020\Exam\Exampredictions3.csv',index=False)

# %%
final = final.rename(columns={'0': 'Churn'})

# %%
final.rename(columns={0:'Churn'}, inplace=True)

# %%
# final.isnull().sum()

# %%
sns.swarmplot(x="Churn", y="Age", data=train)
